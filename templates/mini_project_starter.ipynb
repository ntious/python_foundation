# %% [markdown]
# # Mini Project Starter
#
# Use this notebook to build a small Python project in clear steps. The goal is to create a program that uses input, variables, a list, a loop, a decision, and clear output.
#
# Keep your project simple. A clear program you understand is better than a complicated program you cannot explain.

# %% [markdown]
# ## Project Title and Description
#
# **Project title:** Replace this with your project name.
#
# **Short description:** Write 1-2 sentences explaining what your program helps someone do.
#
# Example idea: A budget checker that adds expenses and tells the user whether total spending is within a limit.

# %% [markdown]
# ## Problem Statement
#
# Write the problem your program solves in plain language.
#
# Use this pattern:
#
# 1. The user needs to know or decide something.
# 2. The program collects simple information.
# 3. The program processes that information.
# 4. The program displays a helpful result.

# %% [markdown]
# ## Program Workflow
#
# Build the project using this workflow:
#
# 1. **Get Input:** collect or define values the program needs.
# 2. **Store Data:** keep related values in variables and a list.
# 3. **Process Data:** use arithmetic or a loop to calculate something.
# 4. **Make Decisions:** use an `if` statement to choose a message or result.
# 5. **Display Output:** print a clear summary for the user.

# %% [markdown]
# ## Step 1: Get Input
#
# Start with a few values. You may use `input()` if your instructor asks for it, or you may use starter values while testing.

# %%
# TODO: Replace the starter values with values for your project.
# If your instructor wants interactive input, replace these values with input() calls.

user_name = "Student"
project_goal = 50

value_1 = 12
value_2 = 18
value_3 = 9

print("User:", user_name)
print("Goal:", project_goal)

# %% [markdown]
# ## Step 2: Store Data
#
# Use a list when you have several related values. Lists work well with loops.

# %%
# TODO: Rename this list if another name fits your project better.

values = [value_1, value_2, value_3]

print("Values:", values)

# %% [markdown]
# ## Step 3: Process Data
#
# Use a loop to process each value. This example adds the values, but your project may count, compare, or build a message.

# %%
total = 0

# TODO: Keep this loop or adapt it for your project.
for value in values:
    total = total + value

print("Total:", total)

# %% [markdown]
# ## Step 4: Make Decisions
#
# Use a condition to decide what message the user should see. Keep the rule simple and explainable.

# %%
# TODO: Change the condition and messages to match your project.

if total <= project_goal:
    result_message = "Within the goal"
else:
    result_message = "Above the goal"

print(result_message)

# %% [markdown]
# ## Step 5: Display Output
#
# The final output should be easy for another person to read. Include labels so the result is clear.

# %%
# TODO: Customize the labels so they match your project.

print("Mini Project Summary")
print("User:", user_name)
print("Values checked:", values)
print("Total:", total)
print("Goal:", project_goal)
print("Result:", result_message)

# %% [markdown]
# ## Example Input and Output
#
# Example starter values:
#
# ```text
# user_name = "Student"
# project_goal = 50
# values = [12, 18, 9]
# ```
#
# Example output:
#
# ```text
# Mini Project Summary
# User: Student
# Values checked: [12, 18, 9]
# Total: 39
# Goal: 50
# Result: Within the goal
# ```

# %% [markdown]
# ## Requirements Checklist
#
# Before submitting, check that your project includes:
#
# - [ ] input or starter values
# - [ ] variables with clear names
# - [ ] at least one list
# - [ ] at least one loop
# - [ ] at least one conditional statement
# - [ ] arithmetic or simple processing
# - [ ] clear final output
# - [ ] comments or explanations where helpful

# %% [markdown]
# ## Testing Section
#
# Test your project with more than one set of values.
#
# Try:
#
# 1. values that are below the goal
# 2. values that are exactly at the goal
# 3. values that are above the goal
#
# After each test, ask: Does the output make sense?

# %%
# Testing notes
# TODO: Write one test you tried and what happened.

test_note = "I tested ... and the result was ..."
print(test_note)

# %% [markdown]
# ## Reflection
#
# Answer in your own words:
#
# 1. What does your program do?
# 2. What problem does it solve?
# 3. What was one challenge you faced?
# 4. How did you test or fix your program?
# 5. How could this kind of program apply to school, work, or your field?
